# %%
# Import necessary packages

import pandas as pd
import os
import shutil

# %%
# Create the data for positive samples
# First parser the file which is availble in chestxray dataset.. file name is metadata.csv

FILE_PATH = "chestxray/metadata.csv"
# parser the image folder

IMAGES_PATH ="chestxray/images"

# %%
# read the metadat file using pandas
df = pd.read_csv(FILE_PATH)
# print no of rows and lows
print(df.shape)
# Out:
# (930, 29)

# %%
#know the structure
df.head()
# Out:
#   patientid  offset sex   age   finding RT_PCR_positive survival intubated  \
# 0         2     0.0   M  65.0  COVID-19               Y        Y         N
# 1         2     3.0   M  65.0  COVID-19               Y        Y         N
# 2         2     5.0   M  65.0  COVID-19               Y        Y         N
# 3         2     6.0   M  65.0  COVID-19               Y        Y         N
# 4         4     0.0   F  52.0  COVID-19               Y      NaN         N
#
#   intubation_present went_icu  ... modality              date  \
# 0                  N        N  ...    X-ray  January 22, 2020
# 1                  N        N  ...    X-ray  January 25, 2020
# 2                  N        N  ...    X-ray  January 27, 2020
# 3                  N        N  ...    X-ray  January 28, 2020
# 4                  N        N  ...    X-ray  January 25, 2020
#
#                                             location  folder  \
# 0        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# ...

# %%
#create a folder called  dataset where we will place the covid images
# use os module to create a folder called covid and move covid images in to that folder


TARGET_DIR = "Dataset/Covid"
if not os.path.exists(TARGET_DIR):
    os.mkdir(TARGET_DIR)
    print("Covid folder created")

# %%
# check how many covid images are there we have 
cnt = 0
for (i,row) in df.iterrows():
    if row["finding"]=="COVID-19" and row["view"]=="PA":  #check for covid images and find the front view with elemenate(PA)
        filename = row["filename"]   # from metadat
        image_path = os.path.join(IMAGES_PATH, filename)
        image_copy_path = os.path.join(TARGET_DIR, filename)  # copy images from original to target dir
        shutil.copy2(image_path,image_copy_path)
       # print("Moving Image", cnt)
        cnt += 1
        
print(cnt)
# Out:
# 180

# %%
#sampling of images from Kaggle
import random
KAGGLE_FILE_PATH = "chest_xray_kaggle/train/NORMAL"
TARGET_NORMAL_DIR = "Dataset/Normal"

# %%
image_names = os.listdir(KAGGLE_FILE_PATH)
#image_names

# %%
random.shuffle(image_names)

# %%
for i in range(180):
    image_name = image_names[i]
    image_path = os.path.join(KAGGLE_FILE_PATH, image_name)
    target_path = os.path.join(TARGET_NORMAL_DIR,image_name)
    shutil.copy2(image_path,target_path)
    print("Copying Image", i)
# Out:
# Copying Image 0
# Copying Image 1
# Copying Image 2
# Copying Image 3
# Copying Image 4
# Copying Image 5
# Copying Image 6
# Copying Image 7
# Copying Image 8
# Copying Image 9
# Copying Image 10
# Copying Image 11
# Copying Image 12
# Copying Image 13
# Copying Image 14
# Copying Image 15
# Copying Image 16
# Copying Image 17
# Copying Image 18
# Copying Image 19
# Copying Image 20
# Copying Image 21
# Copying Image 22
# Copying Image 23
# Copying Image 24
# Copying Image 25
# Copying Image 26
# Copying Image 27
# Copying Image 28
# Copying Image 29
# Copying Image 30
# Copying Image 31
# Copying Image 32
# Copying Image 33
# Copying Image 34
# Copying Image 35
# Copying Image 36
# Copying Image 37
# Copying Image 38
# Copying Image 39
# Copying Image 40
# Copying Image 41
# Copying Image 42
# Copying Image 43
# Copying Image 44
# Copying Image 45
# Copying Image 46
# Copying Image 47
# Copying Image 48
# Copying Image 49
# Copying Image 50
# Copying Image 51
# Copying Image 52
# ...
